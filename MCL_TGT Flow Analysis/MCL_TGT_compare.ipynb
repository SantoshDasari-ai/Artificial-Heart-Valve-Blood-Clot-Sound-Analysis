# %%
import matplotlib.pyplot as plt

# --- Dataset 1 (Actual Human Heart Flow) ---
time1 = [
    6.55, 6.56, 6.57, 6.58, 6.59, 6.6, 6.61, 6.62, 6.63, 6.64, 6.65, 6.66, 6.67, 6.68, 6.69,
    6.7, 6.71, 6.72, 6.73, 6.74, 6.75, 6.76, 6.77, 6.78, 6.79, 6.8, 6.81, 6.82, 6.83, 6.84,
    6.85, 6.86, 6.87, 6.88, 6.89, 6.9, 6.91, 6.92, 6.93, 6.94, 6.95, 6.96, 6.97, 6.98, 6.99,
    7, 7.01, 7.02, 7.03, 7.04, 7.05, 7.06, 7.07, 7.08, 7.09, 7.1, 7.11, 7.12, 7.13, 7.14,
    7.15, 7.16, 7.17, 7.18, 7.19, 7.2, 7.21, 7.22, 7.23, 7.24, 7.25, 7.26, 7.27, 7.28, 7.29,
    7.3, 7.31, 7.32, 7.33, 7.34, 7.35, 7.36, 7.37, 7.38, 7.39, 7.4, 7.41, 7.42, 7.43, 7.44,
    7.45, 7.46, 7.47, 7.48, 7.49, 7.5, 7.51, 7.52, 7.53, 7.54, 7.55
]
flow_rate1 = [
    -0.582812, -1.08438, -0.829688, -0.851562, -0.453125, -0.479687, -0.154688, -0.114062,
    0.0640625, 0.257812, -0.021875, -0.44375, -0.935937, -1.13594, -0.792188, -0.709375,
    -0.321875, -0.284375, -0.3375, -0.0015625, -0.173437, -0.279687, -0.509375, -0.50625,
    -0.414062, -0.0171875, 0.659375, 1.96719, 3.3625, 4.61406, 6.85938, 9.02656, 11.4375,
    14.3766, 17.5703, 21.0828, 23.6625, 26.6234, 28.55, 30.3859, 29.9766, 30.7141, 29.3422,
    26.8516, 27.2812, 24.8719, 23.5109, 20.7703, 17.9875, 15.5813, 13.8047, 10.0266,
    7.49688, 5.11406, 3.59219, 2.8375, 2.1, 1.69531, 1.31875, 1.35938, 1.27031, 0.229687,
    -0.421875, -1.10625, -1.45469, -1.43594, -1.7125, -2.30625, -3.42188, -4.19844,
    -4.65313, -5.40937, -6.95469, -7.51406, -5.56406, -0.0609375, -0.59375, 0.1125,
    0.564063, 0.7625, 0.178125, 0.0265625, -0.267188, -0.475, -0.496875, -0.528125,
    -0.107813, -0.0703125, 0.426563, 0.867188, 0.832812, 0.16875, 0.078125, -0.0390625,
    -0.173437, 0.0015625, -0.065625, 0.0015625, -0.123438, -0.15, -0.028125
]

# --- Dataset 2 (Different Machine) ---
time2 = [
    9.15, 9.16, 9.17, 9.18, 9.19, 9.2, 9.21, 9.22, 9.23, 9.24, 9.25, 9.26, 9.27, 9.28, 9.29,
    9.3, 9.31, 9.32, 9.33, 9.34, 9.35, 9.36, 9.37, 9.38, 9.39, 9.4, 9.41, 9.42, 9.43, 9.44,
    9.45, 9.46, 9.47, 9.48, 9.49, 9.5, 9.51, 9.52, 9.53, 9.54, 9.55, 9.56, 9.57, 9.58, 9.59,
    9.6, 9.61, 9.62, 9.63, 9.64, 9.65, 9.66, 9.67, 9.68, 9.69, 9.7, 9.71, 9.72, 9.73, 9.74,
    9.75, 9.76, 9.77, 9.78, 9.79, 9.8, 9.81, 9.82, 9.83, 9.84, 9.85, 9.86, 9.87, 9.88, 9.89,
    9.9, 9.91, 9.92, 9.93, 9.94, 9.95, 9.96, 9.97, 9.98, 9.99, 10, 10.01, 10.02, 10.03,
    10.04, 10.05, 10.06, 10.07, 10.08, 10.09, 10.1, 10.11, 10.12, 10.13, 10.14, 10.15,
    10.16, 10.17, 10.18, 10.19, 10.2, 10.21, 10.22, 10.23, 10.24, 10.25, 10.26, 10.27,
    10.28, 10.29, 10.3, 10.31, 10.32, 10.33, 10.34, 10.35, 10.36, 10.37, 10.38, 10.39,
    10.4
]
flow_rate2 = [
    -0.214062, 1.11875, 1.37187, 1.25469, 0.046875, 0.24375, -0.789062, -0.159375, 0.0703125,
    0.7375, 1.3875, 1.27656, 2.75469, 4.47031, 6.18594, 7.05938, 7.77031, 8.4625, 8.14219,
    9.81563, 9.81406, 9.37656, 11.5344, 11.5078, 12.3625, 13.2281, 12.5594, 14.1078,
    14.3281, 12.8078, 16.6359, 16.7, 16.4859, 17.5469, 16.2531, 20, 18.1828, 17.0281,
    15.5656, 17.8094, 14.5062, 14.7391, 16.1859, 13.2594, 14.9563, 14.8969, 13.1813,
    12.7734, 14.1953, 13.8578, 12.4875, 11.6813, 12.4781, 11.0938, 12.2438, 11.9844,
    11.1891, 11.9656, 11.5625, 12.0578, 11.4375, 9.93594, 8.7375, 10.2422, 9.21094,
    10.9156, 10.1109, 9.89844, 9.70937, 9.42031, 8.59375, 9.00313, 8.20625, 7.40469,
    7.875, 8.71406, 9.26094, 9.10625, 9.24219, 8.98125, 8.03281, 6.52031, 6.78281,
    7.37812, 7.37969, 7.31562, 7.58281, 8.04219, 8.47031, 8.47656, 7.26406, 6.46875,
    5.91719, 5.58437, 5.92656, 6.51094, 6.75312, 6.72969, 6.40937, 6.1, 7.24375, 6.60625,
    5.96563, 5.49062, 5.39219, 5.05312, 5.61562, 3.64062, 3.00156, 0.825, -0.28125,
    -0.63125, -1.16562, -2.39062, -3.62188, -4.06406, -4.93906, -4.01875, -2.04062,
    0.146875, 0.3, 1.29531, 1.6375, 0.503125, -0.973437, -0.970313
]

# Normalize the time axes for both datasets
def normalize_time(time_series):
    start_time = time_series[0]
    end_time = time_series[-1]
    duration = end_time - start_time
    normalized_time = [(t - start_time) / duration for t in time_series]
    return normalized_time

normalized_time1 = normalize_time(time1)
normalized_time2 = normalize_time(time2)

# Plotting the data with enhanced descriptions
plt.figure(figsize=(14, 8))

# Plot Dataset 1
plt.plot(normalized_time1, flow_rate1, label='Dataset 1 (MCL)', color='blue', linewidth=2)

# Plot Dataset 2
plt.plot(normalized_time2, flow_rate2, label='Dataset 2 (TGT)', color='red', linewidth=2)

# Annotate peak flow rates
peak_index1 = flow_rate1.index(max(flow_rate1))
peak_time1 = normalized_time1[peak_index1]
peak_flow1 = max(flow_rate1)
plt.plot(peak_time1, peak_flow1, 'bo')
plt.annotate(f'Peak Flow: {peak_flow1:.1f} L/min',
             xy=(peak_time1, peak_flow1),
             xytext=(peak_time1 - 0.15, peak_flow1 + 2),
             arrowprops=dict(facecolor='blue', arrowstyle='->'),
             fontsize=12, color='blue',
             ha='right')

peak_index2 = flow_rate2.index(max(flow_rate2))
peak_time2 = normalized_time2[peak_index2]
peak_flow2 = max(flow_rate2)
plt.plot(peak_time2, peak_flow2, 'ro')
plt.annotate(f'Peak Flow: {peak_flow2:.1f} L/min',
             xy=(peak_time2, peak_flow2),
             xytext=(peak_time2 + 0.05, peak_flow2 + 2),
             arrowprops=dict(facecolor='red', arrowstyle='->'),
             fontsize=12, color='red',
             ha='left')

# # Highlight timing discrepancies
# plt.axvline(x=peak_time1, color='blue', linestyle=':', linewidth=1)
# plt.axvline(x=peak_time2, color='red', linestyle=':', linewidth=1)
# plt.text((peak_time1 + peak_time2)/2, max(peak_flow1, peak_flow2) + 5,
#          'Timing Difference', ha='center', color='purple', fontsize=12)


# Set titles and labels
plt.xlabel('Normalized Time (1 Cardiac Cycle)', fontsize=14)
plt.ylabel('Flow Rate (L/min)', fontsize=14)
plt.title('Comparison of Flow Rates Between Two Machines', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)

# # Add shaded areas to represent systole and diastole phases
# systole_start1 = 0.2
# systole_end1 = 0.4
# plt.axvspan(systole_start1, systole_end1, color='yellow', alpha=0.2, label='Systole (MCL)')

# systole_start2 = 0.15
# systole_end2 = 0.35
# plt.axvspan(systole_start2, systole_end2, color='orange', alpha=0.2, label='Systole (TGT)')

# Adjust legend to avoid overlap
plt.legend(fontsize=12, loc='upper right')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
